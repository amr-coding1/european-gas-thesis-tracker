# %% [markdown]
# # Long TTF Summer 2026 — Qatar LNG Supply Shock
#
# **Author:** Abdulrahman Mustafa
# **Date Initiated:** 22 March 2026
# **Direction:** LONG TTF Q3-2026
# **Paper Trade Entry:** €59.34/MWh (22 March 2026)
# **Thesis Score:** Updated live below
#
# ---
#
# ## What This Notebook Does
#
# This is a **live, dynamically-updating trading thesis**. Every time you run it, it pulls fresh data from the European gas storage API (AGSI), recalculates the thesis health score, updates the charts, and shows whether the trade is strengthening or weakening. It is not a static document — it is a working analytical tool.
#
# ---
#
# ## Background: How European Gas Works
#
# Europe heats its homes, runs its power plants, and fuels its industry with natural gas. Unlike the US (which produces most of its own gas), Europe **imports** the majority of its supply — historically from Russia via pipeline, and increasingly from global LNG (Liquefied Natural Gas) shipped by tanker from Qatar, the US, and elsewhere.
#
# **TTF (Title Transfer Facility)** is the European gas benchmark, priced in the Netherlands. It is to European gas what Brent is to oil — the reference price that all contracts, utilities, and industrial buyers anchor to. When we say "European gas prices," we mean TTF.
#
# **Gas storage** is critical because demand is seasonal — Europe burns far more gas in winter (heating) than summer. To survive each winter, Europe fills underground storage caverns during the summer "injection season" (April-October), then draws them down during winter "withdrawal season" (November-March). The EU passed a law after the 2022 energy crisis requiring member states to fill storage to at least **90%** capacity by November each year (since amended — see below).
#
# ---
#
# ## The Event: What Happened at Ras Laffan
#
# On 18-19 March 2026, Iranian missile strikes hit Qatar's **Ras Laffan Industrial City** — the single largest LNG production complex on Earth, responsible for roughly **20% of global LNG supply**.
#
# The strikes destroyed **Train 4** and **Train 6** — two of the facility's liquefaction units. A "train" is a self-contained processing line that cools natural gas to -162°C, converting it to liquid for shipping. These are among the most complex pieces of industrial engineering ever built.
#
# **The damage:**
# - **12.8 million tonnes per annum (mtpa)** of LNG capacity destroyed — approximately 17% of Qatar's total output
# - **$20 billion per year** in lost revenue (QatarEnergy's own estimate)
# - **3-5 years** to repair — liquefaction trains require specialised equipment (cryogenic heat exchangers, gas turbines) with 18-24 month lead times. Money cannot buy time on engineering constraints.
# - **Force majeure** declared on long-term supply contracts to **Italy, Belgium, South Korea, and China**
# - Shell (joint venture partner) also declared force majeure
#
# **Why this matters more than a typical disruption:** This is **physical destruction of production infrastructure**, not a sanctions regime or shipping blockade that can be reversed by political decision. Even if every geopolitical tension resolved tomorrow, those 12.8 mtpa of LNG physically cannot be produced until the trains are rebuilt. The molecules do not exist.
#
# Additionally, the **Pearl GTL facility** (operated by Shell) at Ras Laffan lost one of its two trains, expected offline for at least one year.
#
# ---
#
# ## The Catalyst: Strait of Hormuz Blockade
#
# Compounding the production destruction, Iran **closed the Strait of Hormuz** to foreign shipping on 2 March 2026, following US-Israeli strikes on Iranian military targets. The strait is a narrow waterway through which approximately **20% of global oil** and a significant portion of global LNG transits.
#
# On 5 March, Iran shifted to a **selective blockade** — closed to US, Israeli, and Western-allied vessels, but allowing ships from India, China, Pakistan, and Malaysia to pass. Iran is developing a formal vetting system for transit.
#
# On 19 March, the **US began an aerial campaign** to reopen the strait.
#
# **Impact on the thesis:** Even Qatar's *remaining* operational LNG trains cannot freely export while Hormuz is contested. This means the supply disruption is not limited to the destroyed trains — it extends to all Gulf LNG shipments to Western buyers.
#
# ---
#
# ## The Core Thesis
#
# European gas storage is critically low, and Europe is about to enter "injection season" — the period when it must refill its underground storage to survive next winter. The maths required to refill storage does not work without Qatari LNG, and there is no substitute supply source large enough to fill the gap. Therefore, **TTF (the European gas price) must rise significantly** to:
#
# 1. **Attract marginal LNG cargoes from Asia** — US LNG tankers go to whoever pays the most. If Europe needs them more than Asia, TTF must trade at a premium to JKM (the Asian LNG benchmark).
# 2. **Ration European demand** — at sufficiently high prices, energy-intensive industries (fertilisers, chemicals, glass, steel) shut down, reducing gas consumption and making the refill achievable with less supply.
#
# This is the commodity market's fundamental balancing mechanism: when supply is constrained and inventories are low, **price must rise until supply and demand rebalance.**
#
# ---
#
# ## Why the Thesis Is Bullish (The Case FOR Higher TTF)
#
# ### 1. The refill maths does not work
# EU storage is at approximately **28.5%**. The EU mandate requires at least 80% (recommended) to 90% by December 1. Even at the loosest possible interpretation (70% floor), Europe needs to inject at **2-3x its current daily rate, every single day, for 7+ months**. This has never been achieved in any prior injection season, and that was *with* Qatari LNG flowing freely.
#
# ### 2. Netherlands storage is nearly empty
# The Netherlands — where TTF is physically priced — is at approximately **7% storage**. This translates to roughly **34 days of gas remaining** at current withdrawal rates. The country where Europe's benchmark gas price is set is running on fumes.
#
# ### 3. There is no swing supplier
# - **Norway:** Pipeline gas is running at maximum. North Sea fields are mature and declining.
# - **US LNG:** The largest source of flexible supply, but terminals are already operating near capacity. New capacity (Golden Pass, Plaquemines) is ramping but won't be fully online for summer 2026. And cargoes go to the highest bidder — Asia is competing for the same ships.
# - **Qatar (remaining):** Hormuz blockade constrains exports even from undamaged trains.
# - **Russia:** The EU formally banned Russian gas imports in January 2026, with full phase-out by 2027. Nord Stream pipelines are physically destroyed. Ukraine transit expired. Only TurkStream (~15 bcm/yr) still flows.
# - **Algeria/Libya:** Small pipeline volumes to Southern Europe. Unreliable and declining.
# - **Domestic EU production:** Groningen (Netherlands) permanently shut. UK North Sea declining 5-8% per year.
#
# ### 4. The EU banned Russian gas — permanently
# In January 2026, the EU Council adopted a regulation prohibiting Russian LNG and pipeline gas imports, with full phase-out by end of 2027. This was previously the **#1 bear risk** to this thesis — the possibility that sanctions could be eased if prices got too painful. That option is now closed by law. Russia has responded by threatening to cut off remaining flows preemptively.
#
# ### 5. Asia is competing for the same LNG cargoes
# Qatar's force majeure didn't just hit European buyers — it also hit **South Korea and China**, the world's 2nd and 3rd largest LNG importers. Both are now scrambling for replacement cargoes from the same pool of US and Australian LNG that Europe needs. This is a global tightening, not just a European one.
#
# ### 6. The price confirms the thesis
# TTF has already moved from ~€30-35/MWh (pre-strikes) to ~€59/MWh. The market is beginning to price the supply shock, but the full implications of the refill maths haven't been tested yet — that comes when injection season data starts printing in April.
#
# ### 7. Theory of storage supports the trade
# When inventories are critically low, the **convenience yield** (the value of having physical gas available right now) spikes. This pushes spot prices above futures prices (backwardation), incentivising immediate delivery and discouraging storage — which paradoxically makes the refilling problem worse. It's a self-reinforcing cycle that persists until the physical market rebalances.
#
# ---
#
# ## Why the Thesis Could Be Wrong (The Case AGAINST)
#
# ### 1. Ceasefire and Hormuz reopening
# The US aerial campaign could succeed in reopening the Strait, or diplomatic channels could produce a ceasefire. If Hormuz reopens fully, Qatar's undamaged trains can resume exports and the supply picture improves significantly — though the 12.8 mtpa of destroyed capacity remains offline regardless.
#
# ### 2. EU lowers the storage mandate further
# The EU has already shown flexibility — recommending 80% instead of 90%, with a floor as low as 70% and a deadline pushed to December 1. If they drop the target further (say, to 60%), the urgency and panic premium in TTF collapses. Politicians may accept lower storage if the alternative is factory closures and voter backlash from high energy bills.
#
# ### 3. Demand destruction
# High gas prices are self-correcting. At €80-100/MWh, European fertiliser plants, chemical facilities, and heavy industry shut down. This reduces gas demand, making the storage refill easier. The question is not *whether* demand destruction happens, but *at what price level* — and whether that level is above or below the current price. This risk is also partially the thesis itself: TTF needs to rise to the level that triggers demand destruction.
#
# ### 4. US LNG capacity additions
# New US export terminals (Golden Pass, Plaquemines expansion) are ramping through 2026. If they reach full production faster than expected, there are more cargoes available globally. However, this new capacity was largely pre-contracted (much of it to Asia), and even at full output it doesn't fully replace 12.8 mtpa of Qatari losses on top of the existing Russian gap.
#
# ### 5. Mild summer weather
# A cool European summer significantly reduces gas demand — less air conditioning load means less gas burn in power plants. In a mild summer, the refill maths becomes more achievable. Weather is the highest-variance unknown and cannot be modelled. A 2-standard-deviation cool summer combined with maximum US LNG flows could potentially close the gap.
#
# ### 6. Russian LNG shadow flows
# Despite the import ban, Russian LNG from Yamal and Arctic LNG-2 is already reaching Europe through ship-to-ship transfers, dark fleet tankers, and rebranding. If these shadow flows are significantly larger than official statistics suggest, the actual supply gap may be smaller than it appears. Enforcement could also lag behind legislation.
#
# ---
#
# ## The Trade
#
# **Instrument:** TTF Natural Gas Futures — Summer 2026 (Q3) contracts
# **Direction:** Long (buying, expecting price to rise)
# **Entry:** €59.34/MWh on 22 March 2026
# **Target 1:** €80/MWh — take half the position off
# **Target 2:** €100/MWh — close the remainder
# **Stop Loss:** €45/MWh — pre-strike price level. If TTF returns here, the market has fully unwound the supply shock premium and the thesis is wrong.
# **Timeframe:** 3-6 months. The trade works during injection season (April-October) when the refill pace either confirms or denies the thesis.
#
# **What would change my mind:** Hormuz fully reopens AND EU drops mandate below 70% AND April injection data comes in on pace. All three together would break the thesis. Any one alone is insufficient.
#
# ---
#
# *All data below is pulled live from the AGSI API (Gas Infrastructure Europe). Run all cells to update.*

# %%
# ── Load environment variables from .env ──
import os
from pathlib import Path

env_path = Path('.env')
if env_path.exists():
    for line in env_path.read_text().splitlines():
        line = line.strip()
        if line and not line.startswith('#') and '=' in line:
            key, val = line.split('=', 1)
            os.environ[key.strip()] = val.strip()

# ── Setup ──
import sys, os

# Add project root to path (works regardless of CWD)
_nb_dir = os.path.dirname(os.path.abspath(globals().get('__vsc_ipynb_file__', os.getcwd())))
if os.path.exists(os.path.join(_nb_dir, 'config.py')):
    sys.path.insert(0, _nb_dir)
else:
    sys.path.insert(0, os.getcwd())

import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
from datetime import datetime, timedelta
from IPython.display import display, Markdown, HTML
import warnings
warnings.filterwarnings('ignore')

# Style
plt.rcParams.update({
    'figure.figsize': (14, 5),
    'axes.spines.top': False,
    'axes.spines.right': False,
    'axes.grid': True,
    'grid.alpha': 0.3,
    'font.size': 11,
    'figure.facecolor': 'white',
})

# AGSI API config — set your key as env var or replace below
# Free API key from https://agsi.gie.eu
AGSI_KEY = os.environ.get('AGSI_API_KEY', 'YOUR_API_KEY_HERE')
AGSI_URL = 'https://agsi.gie.eu/api'
HEADERS = {'x-key': AGSI_KEY}

COUNTRIES = {
    'EU': {'param': {'type': 'eu'}, 'name': 'EU Aggregate', 'threshold': 30},
    'NL': {'param': {'country': 'NL'}, 'name': 'Netherlands (TTF)', 'threshold': 15},
    'DE': {'param': {'country': 'DE'}, 'name': 'Germany', 'threshold': 25},
    'FR': {'param': {'country': 'FR'}, 'name': 'France', 'threshold': 25},
    'IT': {'param': {'country': 'IT'}, 'name': 'Italy', 'threshold': 30},
    'AT': {'param': {'country': 'AT'}, 'name': 'Austria', 'threshold': 25},
    'BE': {'param': {'country': 'BE'}, 'name': 'Belgium', 'threshold': 25},
}

# Mandate config (single source of truth)
MANDATE_TARGET = 90       # Official target
MANDATE_RECOMMENDED = 80  # EU commissioner recommendation
MANDATE_FLOOR = 70        # Minimum with full flexibility
MANDATE_DEADLINE = datetime(2026, 12, 1)  # Extended from Nov 1 to Dec 1 (2025 amendment)

assert AGSI_KEY != 'YOUR_API_KEY_HERE', 'Set AGSI_API_KEY env var or replace in cell above. Free key from https://agsi.gie.eu'
print('Setup complete. Run all cells to pull live data.')
# Out:
# Setup complete. Run all cells to pull live data.

# %% [markdown]
# ---
# ## 1. Live European Gas Storage

# %%
# ── Pull live storage data from AGSI API ──

def fetch_storage(country_code, date=None):
    params = dict(COUNTRIES[country_code]['param'])
    if date:
        params['date'] = date
    try:
        r = requests.get(AGSI_URL, headers=HEADERS, params=params, timeout=15)
        r.raise_for_status()
        data = r.json()
        if isinstance(data, list) and data:
            return data[0]
        if isinstance(data, dict) and 'data' in data:
            entries = data['data']
            if isinstance(entries, list) and entries:
                return entries[0]
        return data
    except Exception as e:
        print(f'  Error fetching {country_code}: {e}')
        return None

def safe_float(v):
    if v is None or v == '' or v == '-': return None
    try: return float(v)
    except: return None

# Fetch current data
import time
storage = {}
for i, code in enumerate(COUNTRIES):
    if i > 0: time.sleep(0.5)
    d = fetch_storage(code)
    if d:
        storage[code] = {
            'name': COUNTRIES[code]['name'],
            'full_pct': safe_float(d.get('full')),
            'gas_twh': safe_float(d.get('gasInStorage')),
            'capacity_twh': safe_float(d.get('workingGasVolume')),
            'injection': safe_float(d.get('injection')),
            'withdrawal': safe_float(d.get('withdrawal')),
            'net_withdrawal': safe_float(d.get('netWithdrawal')),
            'gas_day': d.get('gasDayStart', '?'),
        }

# Fetch 7-day-ago for trajectory
week_ago = (datetime.now() - timedelta(days=7)).strftime('%Y-%m-%d')
time.sleep(0.5)
prev_eu = fetch_storage('EU', week_ago)
time.sleep(0.5)
prev_nl = fetch_storage('NL', week_ago)

prev_eu_pct = safe_float(prev_eu.get('full')) if prev_eu else None
prev_nl_pct = safe_float(prev_nl.get('full')) if prev_nl else None

# Display
gas_day = storage.get('EU', {}).get('gas_day', '?')
display(Markdown(f'### Storage Snapshot — Gas Day: {gas_day}'))

rows = []
for code, d in storage.items():
    pct = d['full_pct']
    threshold = COUNTRIES[code]['threshold']
    flag = '⚠️ CRITICAL' if pct is not None and pct < threshold else ''
    nw = d['net_withdrawal']
    rows.append({
        'Country': d['name'],
        'Storage %': f"{pct:.2f}%" if pct else 'N/A',
        'Gas (TWh)': f"{d['gas_twh']:.1f}" if d['gas_twh'] else 'N/A',
        'Capacity (TWh)': f"{d['capacity_twh']:.1f}" if d['capacity_twh'] else 'N/A',
        'Net W/D (GWh/d)': f"{nw:+,.0f}" if nw else 'N/A',
        'Status': flag,
    })

df_storage = pd.DataFrame(rows)
display(df_storage.style.set_properties(**{'text-align': 'right'}).set_table_styles(
    [{'selector': 'th', 'props': [('text-align', 'center'), ('font-weight', 'bold')]}]
).hide(axis='index'))

# Weekly change
eu_pct = storage.get('EU', {}).get('full_pct')
nl_pct = storage.get('NL', {}).get('full_pct')

changes = []
if eu_pct and prev_eu_pct:
    delta = eu_pct - prev_eu_pct
    changes.append(f"- **EU:** {prev_eu_pct:.2f}% → {eu_pct:.2f}% ({delta:+.2f}pp {'▼' if delta < 0 else '▲'})")
if nl_pct and prev_nl_pct:
    delta = nl_pct - prev_nl_pct
    changes.append(f"- **Netherlands:** {prev_nl_pct:.2f}% → {nl_pct:.2f}% ({delta:+.2f}pp {'▼' if delta < 0 else '▲'})")

if changes:
    display(Markdown('### Weekly Change (7 days)\n' + '\n'.join(changes)))
# Out:
# ### Storage Snapshot — Gas Day: 2026-03-28
# <style type="text/css">
# #T_0cd21 th {
#   text-align: center;
#   font-weight: bold;
# }
# #T_0cd21_row0_col0, #T_0cd21_row0_col1, #T_0cd21_row0_col2, #T_0cd21_row0_col3, #T_0cd21_row0_col4, #T_0cd21_row0_col5, #T_0cd21_row1_col0, #T_0cd21_row1_col1, #T_0cd21_row1_col2, #T_0cd21_row1_col3, #T_0cd21_row1_col4, #T_0cd21_row1_col5, #T_0cd21_row2_col0, #T_0cd21_row2_col1, #T_0cd21_row2_col2, #T_0cd21_row2_col3, #T_0cd21_row2_col4, #T_0cd21_row2_col5, #T_0cd21_row3_col0, #T_0cd21_row3_col1, #T_0cd21_row3_col2, #T_0cd21_row3_col3, #T_0cd21_row3_col4, #T_0cd21_row3_col5, #T_0cd21_row4_col0, #T_0cd21_row4_col1, #T_0cd21_row4_col2, #T_0cd21_row4_col3, #T_0cd21_row4_col4, #T_0cd21_row4_col5, #T_0cd21_row5_col0, #T_0cd21_row5_col1, #T_0cd21_row5_col2, #T_0cd21_row5_col3, #T_0cd21_row5_col4, #T_0cd21_row5_col5, #T_0cd21_row6_col0, #T_0cd21_row6_col1, #T_0cd21_row6_col2, #T_0cd21_row6_col3, #T_0cd21_row6_col4, #T_0cd21_row6_col5 {
# ...

# %% [markdown]
# ---
# ## 2. The Refill Maths

# %%
# ── Refill calculations for different mandate targets ──

eu = storage.get('EU', {})
eu_pct = eu.get('full_pct') or 0
eu_cap = eu.get('capacity_twh') or 1142
current_injection = eu.get('injection') or 0

days_left = max((MANDATE_DEADLINE - datetime.now()).days, 1)

targets = [MANDATE_TARGET, MANDATE_RECOMMENDED, 75, MANDATE_FLOOR]
rows = []
for target in targets:
    gap_pct = target - eu_pct
    if gap_pct <= 0:
        continue
    twh_needed = (gap_pct / 100) * eu_cap
    daily_needed = (twh_needed * 1000) / days_left
    ratio = daily_needed / current_injection if current_injection > 0 else float('inf')
    rows.append({
        'Target': f"{target}%",
        'TWh to Inject': f"{twh_needed:.0f}",
        'Days Left': days_left,
        'Required (GWh/d)': f"{daily_needed:,.0f}",
        'Current (GWh/d)': f"{current_injection:,.0f}" if current_injection > 0 else 'N/A',
        'Gap Ratio': f"{ratio:.1f}x" if ratio != float('inf') else 'N/A',
    })

display(Markdown(f'### EU Refill Maths — {days_left} days to December 1 deadline'))
display(pd.DataFrame(rows).style.hide(axis='index'))

# Netherlands days-to-empty
nl = storage.get('NL', {})
nl_gas = nl.get('gas_twh')
nl_nw = nl.get('net_withdrawal')
if nl_gas and nl_nw and nl_nw > 0:
    dte = (nl_gas * 1000) / nl_nw
    display(Markdown(f'### Netherlands: **{dte:.0f} days** of storage remaining at current withdrawal rate'))
# Out:
# ### EU Refill Maths — 247 days to December 1 deadline
# <style type="text/css">
# </style>
# <table id="T_ffcdd">
#   <thead>
#     <tr>
#       <th id="T_ffcdd_level0_col0" class="col_heading level0 col0" >Target</th>
#       <th id="T_ffcdd_level0_col1" class="col_heading level0 col1" >TWh to Inject</th>
#       <th id="T_ffcdd_level0_col2" class="col_heading level0 col2" >Days Left</th>
#       <th id="T_ffcdd_level0_col3" class="col_heading level0 col3" >Required (GWh/d)</th>
#       <th id="T_ffcdd_level0_col4" class="col_heading level0 col4" >Current (GWh/d)</th>
#       <th id="T_ffcdd_level0_col5" class="col_heading level0 col5" >Gap Ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ffcdd_row0_col0" class="data row0 col0" >90%</td>
#       <td id="T_ffcdd_row0_col1" class="data row0 col1" >708</td>
#       <td id="T_ffcdd_row0_col2" class="data row0 col2" >247</td>
#       <td id="T_ffcdd_row0_col3" class="data row0 col3" >2,868</td>
# ...

# %% [markdown]
# ---
# ## 3. 30-Day EU Storage Trend

# %%
# ── Pull 30-day history for EU and NL ──

def fetch_history(code, days=30):
    records = []
    for i in range(days):
        date = (datetime.now() - timedelta(days=i)).strftime('%Y-%m-%d')
        d = fetch_storage(code, date)
        if d:
            pct = safe_float(d.get('full'))
            if pct is not None:
                records.append({'date': pd.Timestamp(date), 'full_pct': pct})
        time.sleep(0.3)
    if not records:
        return pd.DataFrame(columns=['date', 'full_pct'])
    return pd.DataFrame(records).sort_values('date').reset_index(drop=True)

print('Fetching 30-day EU history...')
eu_hist = fetch_history('EU', 30)
print('Fetching 30-day NL history...')
nl_hist = fetch_history('NL', 30)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 5))

# EU chart
if not eu_hist.empty:
    ax1.plot(eu_hist['date'], eu_hist['full_pct'], 'b-', linewidth=2, label='EU Storage %')
    ax1.axhline(y=90, color='green', linestyle='--', alpha=0.5, label='90% mandate')
    ax1.axhline(y=80, color='orange', linestyle='--', alpha=0.5, label='80% (recommended)')
    ax1.axhline(y=70, color='red', linestyle='--', alpha=0.5, label='70% (floor)')
    ax1.fill_between(eu_hist['date'], eu_hist['full_pct'], alpha=0.15, color='blue')
    ax1.set_ylabel('Storage %')
    ax1.set_title('EU Aggregate Storage (30 days)', fontweight='bold')
    ax1.legend(loc='upper right', fontsize=9)
    ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d %b'))
    ax1.set_ylim(0, 100)

# NL chart
if not nl_hist.empty:
    ax2.plot(nl_hist['date'], nl_hist['full_pct'], 'r-', linewidth=2, label='Netherlands Storage %')
    ax2.fill_between(nl_hist['date'], nl_hist['full_pct'], alpha=0.15, color='red')
    ax2.set_ylabel('Storage %')
    ax2.set_title('Netherlands Storage — Where TTF is Priced (30 days)', fontweight='bold')
    ax2.legend(loc='upper right', fontsize=9)
    ax2.xaxis.set_major_formatter(mdates.DateFormatter('%d %b'))
    ax2.set_ylim(0, max(nl_hist['full_pct'].max() * 1.5, 20))

plt.tight_layout()
plt.show()
# Out:
# Fetching 30-day EU history...
#   Error fetching EU: HTTPSConnectionPool(host='agsi.gie.eu', port=443): Read timed out. (read timeout=15)
#   Error fetching EU: HTTPSConnectionPool(host='agsi.gie.eu', port=443): Read timed out. (read timeout=15)
# Fetching 30-day NL history...

# %% [markdown]
# ---
# ## 4. Thesis Health Score

# %%
# ── Score the thesis against 8 weighted indicators ──

# Manual inputs — update when news breaks
MANUAL = {
    'trains_offline_mtpa': 12.8,
    'hormuz_open': False,           # Selective blockade since March 2
    'geopolitical': 'escalation',   # US aerial campaign started March 19
    'ttf_score': 2,                 # €59/MWh, doubled from pre-strike
    'curve_score': 1,               # Backwardation
}

# Scoring functions (aligned with thesis_scorer.py)
def score_storage(pct):
    if pct is None: return 0
    if pct < 25: return 2
    if pct < 35: return 1
    if pct < 50: return 0
    if pct < 65: return -1
    return -2

def score_nl(pct):
    if pct is None: return 0
    if pct < 10: return 2
    if pct < 20: return 1
    if pct < 40: return 0
    if pct < 60: return -1
    return -2

def score_trajectory(current, prev, injection_season):
    if current is None or prev is None: return 0
    delta = current - prev
    if injection_season:
        if delta < 0: return 2
        if delta < 1.5: return 1
        if delta < 3.0: return 0
        if delta < 5.0: return -1
        return -2
    else:
        if delta < -3.0: return 2
        if delta < -1.5: return 1
        if delta < 0: return 0
        if delta < 1.0: return -1
        return -2

def score_injection(inj, month):
    if inj is None or month < 4 or month > 10: return 0
    if inj < 2000: return 2
    if inj < 3000: return 1
    if inj < 4000: return 0
    if inj < 5000: return -1
    return -2

def score_lng(mtpa, hormuz_open):
    s = 2 if mtpa >= 10 else (1 if mtpa >= 5 else 0)
    if not hormuz_open: s += 1
    return min(s, 2)

def score_geo(level):
    return {'de-escalation': -2, 'ceasefire': -1, 'stable': 0, 'tensions': 1, 'escalation': 2}.get(level, 0)

# Compute
month = datetime.now().month
injection_season = 4 <= month <= 10

indicators = {
    'EU Storage Level':        {'raw': score_storage(eu_pct), 'weight': 2.0},
    'Storage Trajectory (7d)': {'raw': score_trajectory(eu_pct, prev_eu_pct, injection_season), 'weight': 1.5},
    'Netherlands (TTF)':       {'raw': score_nl(nl_pct), 'weight': 1.5},
    'Injection Rate':          {'raw': score_injection(current_injection, month), 'weight': 1.5},
    'TTF Front-Month':         {'raw': MANUAL['ttf_score'], 'weight': 1.0},
    'TTF Curve Shape':         {'raw': MANUAL['curve_score'], 'weight': 1.0},
    'LNG Disruption':          {'raw': score_lng(MANUAL['trains_offline_mtpa'], MANUAL['hormuz_open']), 'weight': 2.0},
    'Geopolitical Risk':       {'raw': score_geo(MANUAL['geopolitical']), 'weight': 1.0},
}

max_possible = sum(v['weight'] * 2 for v in indicators.values())
weighted_sum = sum(v['raw'] * v['weight'] for v in indicators.values())
score = max(0, min(100, ((weighted_sum / max_possible) + 1) * 50))

if score >= 75: signal, color = 'STRONG BULL', 'green'
elif score >= 60: signal, color = 'BULL', 'green'
elif score >= 45: signal, color = 'NEUTRAL', 'orange'
elif score >= 30: signal, color = 'BEAR', 'red'
else: signal, color = 'STRONG BEAR', 'red'

display(HTML(f"""
<div style='background: #1a1a2e; color: white; padding: 20px; border-radius: 10px; text-align: center; margin: 10px 0;'>
    <h2 style='margin:0; color: {color};'>{score:.1f} / 100</h2>
    <h3 style='margin:5px 0; color: {color};'>{signal}</h3>
    <p style='margin:5px 0; color: #aaa;'>Last updated: {datetime.now().strftime('%Y-%m-%d %H:%M')}</p>
</div>
"""))

# Indicator breakdown
ind_rows = []
for name, v in indicators.items():
    raw = v['raw']
    direction = 'BULL' if raw > 0 else ('BEAR' if raw < 0 else 'NEUT')
    bar = '█' * abs(raw) + '░' * (2 - abs(raw))
    ind_rows.append({
        'Indicator': name,
        'Score': f"{raw:+d}",
        'Weight': f"x{v['weight']:.1f}",
        'Strength': f"[{bar}]",
        'Signal': direction,
    })

display(pd.DataFrame(ind_rows).style.hide(axis='index'))
# Out:
# <div style='background: #1a1a2e; color: white; padding: 20px; border-radius: 10px; text-align: center; margin: 10px 0;'>
#     <h2 style='margin:0; color: green;'>80.4 / 100</h2>
#     <h3 style='margin:5px 0; color: green;'>STRONG BULL</h3>
#     <p style='margin:5px 0; color: #aaa;'>Last updated: 2026-03-28 23:29</p>
# </div>
# <style type="text/css">
# </style>
# <table id="T_e2258">
#   <thead>
#     <tr>
#       <th id="T_e2258_level0_col0" class="col_heading level0 col0" >Indicator</th>
#       <th id="T_e2258_level0_col1" class="col_heading level0 col1" >Score</th>
#       <th id="T_e2258_level0_col2" class="col_heading level0 col2" >Weight</th>
#       <th id="T_e2258_level0_col3" class="col_heading level0 col3" >Strength</th>
#       <th id="T_e2258_level0_col4" class="col_heading level0 col4" >Signal</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e2258_row0_col0" class="data row0 col0" >EU Storage Level</td>
# ...

# %% [markdown]
# ---
# ## 5. Supply Picture

# %%
# ── Visualise the supply constraint ──

supply_data = {
    'Source': ['Norway\n(pipeline)', 'US LNG', 'Qatar LNG\n(remaining)', 'Qatar LNG\n(destroyed)', 
              'Russia\n(pipeline)', 'Russia\n(LNG)', 'Algeria/Libya', 'Domestic\n(EU)'],
    'Capacity (bcm/yr)': [120, 85, 65, 0, 15, 15, 25, 20],
    'Available (bcm/yr)': [120, 70, 30, 0, 5, 10, 20, 18],
    'Status': ['Maxed', 'Near max', 'Hormuz blocked', 'Destroyed', 
               'Banned by EU', 'Dark fleet only', 'Unreliable', 'Declining'],
}
df_supply = pd.DataFrame(supply_data)

fig, ax = plt.subplots(figsize=(14, 5))
x = range(len(df_supply))
colors = ['#2ecc71', '#2ecc71', '#e74c3c', '#c0392b', '#95a5a6', '#95a5a6', '#f39c12', '#f39c12']

bars_cap = ax.bar(x, df_supply['Capacity (bcm/yr)'], width=0.4, label='Nameplate capacity', 
                   alpha=0.3, color='gray', align='center')
bars_avail = ax.bar([i+0.4 for i in x], df_supply['Available (bcm/yr)'], width=0.4, 
                     label='Currently available', color=colors, align='center')

ax.set_xticks([i+0.2 for i in x])
ax.set_xticklabels(df_supply['Source'], fontsize=9)
ax.set_ylabel('bcm/year')
ax.set_title('European Gas Supply Sources — Capacity vs Available', fontweight='bold')
ax.legend()

# Annotate status
for i, status in enumerate(df_supply['Status']):
    y = max(df_supply['Capacity (bcm/yr)'].iloc[i], df_supply['Available (bcm/yr)'].iloc[i])
    ax.text(i + 0.2, y + 2, status, ha='center', fontsize=8, style='italic', color='#555')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 6. Country-by-Country Storage Heatmap

# %%
# ── Storage levels as a visual heatmap ──

countries = [d['name'] for d in storage.values()]
pcts = [d['full_pct'] if d['full_pct'] else 0 for d in storage.values()]
thresholds = [COUNTRIES[c]['threshold'] for c in storage.keys()]

fig, ax = plt.subplots(figsize=(14, 4))

# Color based on how critical
bar_colors = []
for pct, thresh in zip(pcts, thresholds):
    if pct < thresh * 0.5:
        bar_colors.append('#c0392b')  # Dark red — extremely critical
    elif pct < thresh:
        bar_colors.append('#e74c3c')  # Red — critical
    elif pct < 50:
        bar_colors.append('#f39c12')  # Orange — below normal
    elif pct < 80:
        bar_colors.append('#2ecc71')  # Green — healthy
    else:
        bar_colors.append('#27ae60')  # Dark green — full

bars = ax.barh(countries, pcts, color=bar_colors, height=0.6)
ax.axvline(x=90, color='green', linestyle='--', alpha=0.5, label='90% mandate')
ax.axvline(x=80, color='orange', linestyle='--', alpha=0.5, label='80% recommended')
ax.axvline(x=70, color='red', linestyle='--', alpha=0.5, label='70% floor')

for bar, pct in zip(bars, pcts):
    ax.text(pct + 1, bar.get_y() + bar.get_height()/2, f'{pct:.1f}%', 
            va='center', fontweight='bold', fontsize=10)

ax.set_xlim(0, 100)
ax.set_xlabel('Storage %')
ax.set_title('European Gas Storage by Country', fontweight='bold')
ax.legend(loc='lower right', fontsize=9)
ax.invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 7. Paper Trade Tracker

# %%
# ── Paper trade parameters ──
import yfinance as yf

ENTRY_DATE = '2026-03-22'
ENTRY_PRICE = 59.34
STOP_LOSS = 45.00
TARGET_1 = 80.00
TARGET_2 = 100.00

# Try to pull live TTF price from Yahoo Finance
try:
    ttf = yf.Ticker("TTF=F")
    hist = ttf.history(period="5d")
    if not hist.empty:
        CURRENT_PRICE = hist['Close'].iloc[-1]
        price_date = hist.index[-1].strftime('%Y-%m-%d')
        price_source = f"Yahoo Finance ({price_date})"
    else:
        raise ValueError("No data")
except:
    CURRENT_PRICE = 59.255  # Fallback — update manually from TradingView
    price_source = "Manual (update from TradingView)"

pnl = CURRENT_PRICE - ENTRY_PRICE
pnl_pct = (pnl / ENTRY_PRICE) * 100
risk = ENTRY_PRICE - STOP_LOSS
reward_1 = TARGET_1 - ENTRY_PRICE
rr_1 = reward_1 / risk if risk > 0 else 0
dist_to_stop = ((CURRENT_PRICE - STOP_LOSS) / CURRENT_PRICE) * 100
dist_to_tp1 = ((TARGET_1 - CURRENT_PRICE) / CURRENT_PRICE) * 100

pnl_color = 'green' if pnl >= 0 else 'red'

display(HTML(f"""
<div style='background: #1a1a2e; color: white; padding: 20px; border-radius: 10px; margin: 10px 0;'>
    <h3 style='margin:0;'>Paper Trade: Long TTF @ €{ENTRY_PRICE:.2f}</h3>
    <table style='color: white; margin-top: 10px; font-size: 14px;'>
        <tr><td style='padding: 5px 20px 5px 0;'>Entry:</td><td>€{ENTRY_PRICE:.2f} ({ENTRY_DATE})</td></tr>
        <tr><td style='padding: 5px 20px 5px 0;'>Current:</td><td>€{CURRENT_PRICE:.2f} <span style='color:#aaa; font-size:12px;'>({price_source})</span></td></tr>
        <tr><td style='padding: 5px 20px 5px 0;'>P&L:</td><td style='color: {pnl_color}; font-weight: bold;'>€{pnl:+.2f}/MWh ({pnl_pct:+.1f}%)</td></tr>
        <tr><td style='padding: 5px 20px 5px 0;'>Stop Loss:</td><td>€{STOP_LOSS:.2f} ({dist_to_stop:.1f}% away)</td></tr>
        <tr><td style='padding: 5px 20px 5px 0;'>Target 1:</td><td>€{TARGET_1:.2f} ({dist_to_tp1:.1f}% away, R:R {rr_1:.1f}:1)</td></tr>
        <tr><td style='padding: 5px 20px 5px 0;'>Target 2:</td><td>€{TARGET_2:.2f}</td></tr>
    </table>
</div>
"""))

days_in_trade = (datetime.now() - pd.Timestamp(ENTRY_DATE)).days
display(Markdown(f'*Day {days_in_trade} of trade. Timeframe: 3-6 months.*'))
# Out:
# <div style='background: #1a1a2e; color: white; padding: 20px; border-radius: 10px; margin: 10px 0;'>
#     <h3 style='margin:0;'>Paper Trade: Long TTF @ €59.34</h3>
#     <table style='color: white; margin-top: 10px; font-size: 14px;'>
#         <tr><td style='padding: 5px 20px 5px 0;'>Entry:</td><td>€59.34 (2026-03-22)</td></tr>
#         <tr><td style='padding: 5px 20px 5px 0;'>Current:</td><td>€54.18 <span style='color:#aaa; font-size:12px;'>(Yahoo Finance (2026-03-27))</span></td></tr>
#         <tr><td style='padding: 5px 20px 5px 0;'>P&L:</td><td style='color: red; font-weight: bold;'>€-5.16/MWh (-8.7%)</td></tr>
#         <tr><td style='padding: 5px 20px 5px 0;'>Stop Loss:</td><td>€45.00 (16.9% away)</td></tr>
#         <tr><td style='padding: 5px 20px 5px 0;'>Target 1:</td><td>€80.00 (47.7% away, R:R 1.4:1)</td></tr>
#         <tr><td style='padding: 5px 20px 5px 0;'>Target 2:</td><td>€100.00</td></tr>
#     </table>
# </div>
# *Day 6 of trade. Timeframe: 3-6 months.*

# %% [markdown]
# ---
# ## 8. Related Positions & Portfolio
#
# *Cross-asset expressions of the same macro thesis. All positions entered as paper trades on TradingView.*

# %%
# ── Related positions: full portfolio tracking ──
import yfinance as yf
from datetime import datetime

POSITIONS = {
    "TTF": {"ticker": "TTF=F", "name": "TTF Gas Q3-26", "dir": "LONG", "entry": 59.34, "tp1": 80.0, "tp2": 100.0, "stop": 45.0, "weight": 0.30, "ccy": "EUR", "unit": "/MWh", "cat": "Gas/LNG"},
    "LNG": {"ticker": "LNG", "name": "Cheniere Energy", "dir": "LONG", "entry": 299.0, "tp1": 335.0, "tp2": None, "stop": 265.0, "weight": 0.25, "ccy": "USD", "unit": "", "cat": "Equities"},
    "VG": {"ticker": "VG", "name": "Venture Global", "dir": "LONG", "entry": 17.50, "tp1": 25.0, "tp2": None, "stop": 12.0, "weight": 0.10, "ccy": "USD", "unit": "", "cat": "Equities"},
    "EQNR": {"ticker": "EQNR", "name": "Equinor ASA", "dir": "LONG", "entry": 41.0, "tp1": 50.0, "tp2": None, "stop": 35.0, "weight": 0.10, "ccy": "USD", "unit": "", "cat": "Equities"},
    "BRENT": {"ticker": "BZ=F", "name": "Brent Crude", "dir": "LONG", "entry": 112.50, "tp1": 130.0, "tp2": None, "stop": 95.0, "weight": 0.10, "ccy": "USD", "unit": "/bbl", "cat": "Oil"},
    "HH": {"ticker": "NG=F", "name": "Henry Hub (Hedge)", "dir": "SHORT", "entry": 2.94, "tp1": 2.20, "tp2": None, "stop": 3.50, "weight": 0.05, "ccy": "USD", "unit": "/MMBtu", "cat": "Gas/LNG"},
}

# Fetch live prices
prices = {}
for key, pos in POSITIONS.items():
    try:
        t = yf.Ticker(pos["ticker"])
        h = t.history(period="5d")
        if not h.empty:
            prices[key] = h['Close'].iloc[-1]
        else:
            prices[key] = pos["entry"]  # fallback to entry
    except:
        prices[key] = pos["entry"]

# Build portfolio table rows
rows = ""
total_weighted_pnl = 0
for key, pos in POSITIONS.items():
    current = prices[key]
    if pos["dir"] == "LONG":
        pnl = current - pos["entry"]
    else:  # SHORT
        pnl = pos["entry"] - current
    pnl_pct = (pnl / pos["entry"]) * 100
    weighted_pnl = pnl_pct * pos["weight"]
    total_weighted_pnl += weighted_pnl

    pnl_color = "#00ff88" if pnl >= 0 else "#ff4444"
    dir_color = "#00ff88" if pos["dir"] == "LONG" else "#ff8844"

    dist_tp = ((pos["tp1"] - current) / current * 100) if pos["dir"] == "LONG" else ((current - pos["tp1"]) / current * 100)
    dist_stop = ((current - pos["stop"]) / current * 100) if pos["dir"] == "LONG" else ((pos["stop"] - current) / current * 100)

    tp2_str = f" / {pos['ccy']} {pos['tp2']:.0f}" if pos["tp2"] else ""

    rows += f"""
        <tr style='border-bottom: 1px solid #333;'>
            <td style='padding:8px;'><strong>{key}</strong><br><span style='color:#aaa;font-size:11px;'>{pos['name']}</span></td>
            <td style='padding:8px;color:{dir_color};'>{pos['dir']}</td>
            <td style='padding:8px;'>{pos['ccy']} {pos['entry']:.2f}</td>
            <td style='padding:8px;'>{pos['ccy']} {current:.2f}</td>
            <td style='padding:8px;color:{pnl_color};font-weight:bold;'>{pnl:+.2f} ({pnl_pct:+.1f}%)</td>
            <td style='padding:8px;'>{pos['weight']*100:.0f}%</td>
            <td style='padding:8px;'>{dist_tp:.1f}%</td>
            <td style='padding:8px;'>{dist_stop:.1f}%</td>
        </tr>"""

total_color = "#00ff88" if total_weighted_pnl >= 0 else "#ff4444"

display(HTML(f"""
<div style='background:#1a1a2e;color:white;padding:20px;border-radius:10px;margin:10px 0;'>
    <h3 style='margin:0 0 15px 0;'>Portfolio Overview</h3>
    <table style='color:white;width:100%;font-size:13px;border-collapse:collapse;'>
        <tr style='border-bottom:2px solid #555;'>
            <th style='padding:8px;text-align:left;'>Position</th>
            <th style='padding:8px;text-align:left;'>Dir</th>
            <th style='padding:8px;text-align:left;'>Entry</th>
            <th style='padding:8px;text-align:left;'>Current</th>
            <th style='padding:8px;text-align:left;'>P&L</th>
            <th style='padding:8px;text-align:left;'>Weight</th>
            <th style='padding:8px;text-align:left;'>To TP1</th>
            <th style='padding:8px;text-align:left;'>To Stop</th>
        </tr>
        {rows}
        <tr style='border-top:2px solid #555;'>
            <td colspan='4' style='padding:8px;font-weight:bold;'>Portfolio Weighted P&L</td>
            <td colspan='4' style='padding:8px;color:{total_color};font-weight:bold;font-size:16px;'>{total_weighted_pnl:+.2f}%</td>
        </tr>
    </table>
    <p style='color:#aaa;font-size:11px;margin:10px 0 0 0;'>Unallocated: 10% cash reserve. Prices from Yahoo Finance.</p>
</div>
"""))

# ── Correlation matrix (30-day) ──
tickers = [pos["ticker"] for pos in POSITIONS.values()]
labels = list(POSITIONS.keys())

try:
    import warnings
    warnings.filterwarnings('ignore')
    data = yf.download(tickers, period="1mo", progress=False)
    if 'Close' in data.columns.get_level_values(0):
        closes = data['Close']
    else:
        closes = data

    if not closes.empty and closes.shape[1] > 1:
        corr = closes.pct_change().dropna().corr()

        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

        # Correlation heatmap
        im = ax1.matshow(corr.values, cmap='RdYlGn', vmin=-1, vmax=1)
        ax1.set_xticks(range(len(labels)))
        ax1.set_yticks(range(len(labels)))
        ax1.set_xticklabels(labels, rotation=45, ha='left', fontsize=10)
        ax1.set_yticklabels(labels, fontsize=10)
        for i in range(len(labels)):
            for j in range(len(labels)):
                ax1.text(j, i, f'{corr.values[i,j]:.2f}', ha='center', va='center', fontsize=9,
                         color='black' if abs(corr.values[i,j]) < 0.7 else 'white')
        plt.colorbar(im, ax=ax1, shrink=0.8)
        ax1.set_title('30-Day Return Correlation', pad=20, fontsize=12)

        # Allocation pie chart
        weights = [pos["weight"] for pos in POSITIONS.values()] + [0.10]
        pie_labels = [f'{k}\n({v["weight"]*100:.0f}%)' for k, v in POSITIONS.items()] + ['Cash\n(10%)']
        colors = ['#4ecdc4', '#45b7d1', '#96ceb4', '#ffeaa7', '#dfe6e9', '#ff7675', '#b2bec3']
        ax2.pie(weights, labels=pie_labels, colors=colors[:len(weights)], startangle=90,
                textprops={'fontsize': 9})
        ax2.set_title('Portfolio Allocation', fontsize=12)

        plt.tight_layout()
        plt.show()
    else:
        print("Insufficient price data for correlation matrix.")
except Exception as e:
    print(f"Could not generate correlation chart: {e}")
# Out:
# <div style='background:#1a1a2e;color:white;padding:20px;border-radius:10px;margin:10px 0;'>
#     <h3 style='margin:0 0 15px 0;'>Portfolio Overview</h3>
#     <table style='color:white;width:100%;font-size:13px;border-collapse:collapse;'>
#         <tr style='border-bottom:2px solid #555;'>
#             <th style='padding:8px;text-align:left;'>Position</th>
#             <th style='padding:8px;text-align:left;'>Dir</th>
#             <th style='padding:8px;text-align:left;'>Entry</th>
#             <th style='padding:8px;text-align:left;'>Current</th>
#             <th style='padding:8px;text-align:left;'>P&L</th>
#             <th style='padding:8px;text-align:left;'>Weight</th>
#             <th style='padding:8px;text-align:left;'>To TP1</th>
#             <th style='padding:8px;text-align:left;'>To Stop</th>
#         </tr>
#
#         <tr style='border-bottom: 1px solid #333;'>
# ...

# %% [markdown]
# ---
# ## 9. Bull / Bear Catalyst Tracker
#
# ### Bull Catalysts
# | Catalyst | Status | Impact |
# |----------|--------|--------|
# | Below-normal injection rates (April/May) | ⏳ Pending — injection season starts April | HIGH |
# | Asian LNG spot prices rising | ✅ JKM elevated, TTF/JKM spread at 3x | MEDIUM |
# | Hormuz escalation | ✅ Selective blockade active, US aerial campaign started | HIGH |
# | Hot European summer | ⏳ Unknown — weather TBD | HIGH |
# | EU reaffirming storage mandate | ⚠️ Partially — lowered to 80% recommended, 70% floor | MEDIUM |
# | Additional LNG outages globally | ⏳ Watching | HIGH |
#
# ### Bear Risks
# | Risk | Status | Impact |
# |------|--------|--------|
# | Russian sanctions relief | ❌ Eliminated — EU banned Russian gas by law (Jan 2026) | was HIGH |
# | Ceasefire / rapid Ras Laffan repair | ⏳ No signs of ceasefire. 3-5 year repair confirmed by QatarEnergy | HIGH |
# | EU drops storage mandate | ⚠️ Partially materialised — effective floor now 70% | MEDIUM |
# | US LNG surge | ⚠️ New capacity coming but running at max. Can't fully replace Qatar | MEDIUM |
# | Mild summer | ⏳ Unknown | HIGH |
# | Demand destruction | ⏳ At €59/MWh, not yet at shutdown levels (~€80-100) | MEDIUM |

# %% [markdown]
# ---
# ## 10. Thought Process & Scenario Analysis
#
# ### Current Thesis Status (2026-03-28)
#
# 10 days since the Ras Laffan strike. No ceasefire. Hormuz still closed. The trade is in the "uncomfortable middle" -- TTF has pulled back from the EUR 74 panic high to ~EUR 54.50, but the fundamentals are actually *worse* than when it was at 74: force majeure is now official, Asia is stealing LNG cargoes ($1-3/MMBtu premium over Europe), and the Russian LNG ban is live.
#
# **The edge:** The market is pricing in some hope of diplomatic resolution. We are betting it doesn't happen -- and every day that passes without a ceasefire, the refill window gets shorter and the eventual repricing gets more violent.
#
# ### Key Developments Since Entry
#
# | Date | Development | Impact |
# |------|------------|--------|
# | 2026-03-02 | Iran closes Strait of Hormuz | Triggers global energy supply shock |
# | 2026-03-18 | Iran strikes Ras Laffan Trains 4 & 6 | Core thesis trigger -- 12.8 MTPA offline |
# | 2026-03-18 | EU Russian LNG ban officially starts | Removes another supply source |
# | 2026-03-22 | **Thesis entry at EUR 59.34** | Paper trade opened |
# | 2026-03-24 | QatarEnergy declares force majeure | Confirms 3-5 year repair timeline |
# | 2026-03-25 | Asia outbidding Europe for LNG | Dozen+ cargoes redirected mid-voyage to Asia |
# | 2026-03-26 | Trump extends Iran deadline to April 6 | Binary event approaching |
# | 2026-03-27 | France seizes shadow fleet tanker *Grinch* | Russian sanctions enforcement is real |
# | 2026-03-28 | Portfolio expanded to 6 positions | Added LNG, VG, EQNR, Brent, short HH |
#
# ### Scenario Analysis
#
# #### Scenario 1: Thesis Plays Out -- No Ceasefire, EU Can't Refill (50% probability)
# - TTF: 59 -> 80-100. Injection data in April/May confirms behind pace.
# - Cheniere/VG: Massive HH-TTF spread persists. Both hit targets.
# - Equinor: Gas revenues elevated all year. Hits $50.
# - Brent: Stays $110-130 on Hormuz premium.
# - Short HH: HH stays flat at ~$2.50-3.50. Small win.
# - **Portfolio: +15-30% weighted.**
#
# #### Scenario 2: Ceasefire / Hormuz Reopens (25% probability)
# - TTF: Drops to 40-48. Stop at 45 limits damage. Ras Laffan still offline = floor.
# - Cheniere/VG: Pull back 15-25%. VG higher beta = bigger drop.
# - Equinor: Drops to $35-37.
# - Brent: Collapses to $85-90. Stop at $95 catches most of the fall.
# - Short HH: Flat to small win (HH barely moves on ceasefire).
# - **Portfolio: -8-15% weighted (stops activated).**
#
# #### Scenario 3: Escalation -- Further Strikes, Wider War (15% probability)
# - TTF: Parabolic. EUR 100+.
# - Cheniere: $350+. VG: $25-30.
# - Equinor: $50+.
# - Brent: $130-150.
# - Short HH: Small loss (HH rises $0.50-1 on general panic).
# - **Portfolio: +25-40% weighted.**
#
# #### Scenario 4: EU Waives Storage Mandate (10% probability)
# - TTF: Drops to 50-55 but supply still disrupted. Partial loss.
# - Equities: Barely affected -- global LNG demand unchanged.
# - Brent: Unrelated. No impact.
# - **Portfolio: -3-5% weighted (diversification limits damage).**
#
# ### The Henry Hub Hedge -- How It Works
#
# The short HH is not a perfect hedge -- it's a **decorrelation play**:
#
# - **US gas is structurally oversupplied.** Production at record highs, export terminals maxed out. HH can't rally even if global gas rips.
# - **The TTF-HH spread (~EUR 12/MMBtu equivalent) is the trade itself.** Cheniere and VG profit from this spread. Shorting HH is betting the US side stays low.
# - **In a ceasefire scenario:** TTF drops, Brent drops, equities drop. But HH was already at $2.94 -- it has very little downside. The short makes a small gain while everything else loses.
# - **Honest assessment:** The hedge covers maybe 5% of portfolio risk in the worst scenario. It's better than nothing, and it shows recruiter-grade portfolio thinking. A real hedge would be put options on TTF or Brent.
#
# ### Key Dates
#
# | Date | Event | Significance |
# |------|-------|-------------|
# | **2026-04-06** | **Trump deadline for Iran** | **Binary event. If no deal: US strikes Iranian energy. If deal: Hormuz reopens, Brent collapses.** |
# | 2026-04 to 05 | First injection data | Confirms whether EU is on pace to refill. Core thesis validation. |
# | Mid-2026 | Plaquemines LNG Phase 1 (VG) | New US export capacity. Catalyst for VG stock. |
# | Late 2026 | Golden Pass LNG online | Additional US capacity. Partially offsets Qatar loss. |
# | 2026-11-01 | EU storage mandate deadline | Must hit 90% (relaxed to 70-80% floor). The ultimate scorecard. |

# %% [markdown]
# ---
# ## 11. Trade Journal
#
# *CSV-backed journal auto-populated by `python3 run_tracker.py --journal`. Data columns are filled automatically; reflection columns (decision, psychology, Seykota check) are entered manually.*

# %%
# ── Trade journal — reads from data/trade_journal.csv ──
import os

JOURNAL_PATH = os.path.join('data', 'trade_journal.csv')

if os.path.exists(JOURNAL_PATH):
    journal_df = pd.read_csv(JOURNAL_PATH)

    if not journal_df.empty:
        # Build styled HTML table
        auto_cols = ['date', 'ttf_price', 'eu_storage_pct', 'nl_storage_pct',
                     'thesis_score', 'portfolio_pnl', 'circuit_breaker', 'positions_summary']
        manual_cols = ['decision', 'psychology', 'seykota_check']

        header = ""
        for col in journal_df.columns:
            color = "#66ccff" if col in manual_cols else "#ddd"
            label = col.replace('_', ' ').title().replace('Pnl', 'P&L').replace('Pct', '%').replace('Ttf', 'TTF').replace('Eu ', 'EU ').replace('Nl ', 'NL ')
            header += f"<th style='padding:6px 8px;color:{color};text-align:left;font-size:11px;'>{label}</th>"

        rows = ""
        for _, row in journal_df.iterrows():
            cells = ""
            for col in journal_df.columns:
                val = row[col]
                if pd.isna(val) or val == '':
                    val = '—'
                color = "#66ccff" if col in manual_cols else "#ddd"

                # Colour P&L
                if col == 'portfolio_pnl' and val != '—':
                    try:
                        pnl_val = float(val)
                        color = "#00ff88" if pnl_val >= 0 else "#ff4444"
                        val = f"{pnl_val:+.2f}%"
                    except (ValueError, TypeError):
                        pass

                # Colour circuit breaker
                if col == 'circuit_breaker' and val != '—':
                    cb_colors = {"GREEN": "#00ff88", "YELLOW": "#ffcc00", "ORANGE": "#ff8800", "RED": "#ff0000"}
                    color = cb_colors.get(str(val), "#ddd")

                cells += f"<td style='padding:6px 8px;color:{color};font-size:11px;max-width:200px;word-wrap:break-word;'>{val}</td>"
            rows += f"<tr style='border-bottom:1px solid #333;'>{cells}</tr>"

        # Summary stats
        n_entries = len(journal_df)
        if 'portfolio_pnl' in journal_df.columns:
            pnl_series = pd.to_numeric(journal_df['portfolio_pnl'], errors='coerce')
            best_week = pnl_series.max()
            worst_week = pnl_series.min()
            latest_pnl = pnl_series.iloc[-1] if not pnl_series.empty else 0
            pnl_stats = f"Best: <span style='color:#00ff88;'>{best_week:+.2f}%</span> | Worst: <span style='color:#ff4444;'>{worst_week:+.2f}%</span> | Latest: {latest_pnl:+.2f}%"
        else:
            pnl_stats = ""

        if 'thesis_score' in journal_df.columns:
            score_series = pd.to_numeric(journal_df['thesis_score'], errors='coerce')
            score_trend = "Stable"
            if len(score_series.dropna()) >= 2:
                diff = score_series.dropna().iloc[-1] - score_series.dropna().iloc[0]
                score_trend = f"{'Strengthening' if diff > 0 else 'Weakening'} ({diff:+.1f})"
        else:
            score_trend = ""

        display(HTML(f"""
        <div style='background:#1a1a2e;color:white;padding:20px;border-radius:10px;margin:10px 0;'>
            <h3 style='margin:0 0 5px 0;'>Trade Journal</h3>
            <p style='color:#aaa;font-size:11px;margin:0 0 15px 0;'>{n_entries} entries | Score trend: {score_trend} | {pnl_stats}</p>
            <div style='overflow-x:auto;'>
            <table style='color:white;width:100%;font-size:12px;border-collapse:collapse;white-space:nowrap;'>
                <tr style='border-bottom:2px solid #555;'>{header}</tr>
                {rows}
            </table>
            </div>
            <p style='color:#888;font-size:10px;margin:10px 0 0 0;'>
                White columns = auto-populated | <span style='color:#66ccff;'>Blue columns</span> = manual reflection
                | Add entries: <code>python3 run_tracker.py --journal</code>
            </p>
        </div>
        """))
    else:
        display(Markdown("*Journal is empty. Run `python3 run_tracker.py --journal` to create your first entry.*"))
else:
    display(Markdown("""*No journal file found.* Create your first entry:

```bash
python3 run_tracker.py --journal
```

This will auto-fill storage data, prices, scores, and portfolio P&L, then prompt you for weekly reflections (decision, psychology, Seykota check)."""))
# Out:
# *No journal file found.* Create your first entry:
#
# ```bash
# python3 run_tracker.py --journal
# ```
#
# This will auto-fill storage data, prices, scores, and portfolio P&L, then prompt you for weekly reflections (decision, psychology, Seykota check).

# %% [markdown]
# ---
# ## 12. Live News & Intelligence Feed
#
# *Pulls latest headlines from Google News RSS, grouped by thesis-relevant categories. Run this cell to refresh.*

# %%
# ── Live news feed — Google News RSS ──
import time
import urllib.parse
from datetime import datetime, timedelta, timezone

try:
    import feedparser
    HAS_FEEDPARSER = True
except ImportError:
    HAS_FEEDPARSER = False
    print("Install feedparser for live news: pip install feedparser")

NEWS_QUERIES = {
    "Gas / LNG": [
        "TTF gas price Europe",
        "Ras Laffan LNG Qatar repair",
        "European gas storage injection 2026",
        "LNG cargo spot market Asia Europe",
        "Strait of Hormuz shipping LNG",
    ],
    "Geopolitical": [
        "Iran war ceasefire negotiations 2026",
        "Trump Iran deadline energy",
        "EU Russian gas ban sanctions",
    ],
    "Equities": [
        "Cheniere Energy LNG stock",
        "Venture Global LNG Plaquemines",
        "Equinor gas production Norway",
    ],
    "Oil": [
        "Brent crude oil price Hormuz",
    ],
}

if HAS_FEEDPARSER:
    all_news = []
    for category, queries in NEWS_QUERIES.items():
        for query in queries:
            try:
                url = f"https://news.google.com/rss/search?q={urllib.parse.quote(query)}&hl=en&gl=US&ceid=US:en"
                feed = feedparser.parse(url)
                for entry in feed.entries[:4]:
                    pub = None
                    if hasattr(entry, 'published_parsed') and entry.published_parsed:
                        pub = datetime(*entry.published_parsed[:6], tzinfo=timezone.utc)
                    source = entry.source.title if hasattr(entry, 'source') and hasattr(entry.source, 'title') else 'Unknown'
                    all_news.append({
                        'title': entry.get('title', 'N/A'),
                        'source': source,
                        'published': pub,
                        'link': entry.get('link', ''),
                        'category': category,
                    })
            except:
                pass
            time.sleep(0.3)

    # Deduplicate and filter last 48 hours
    seen = set()
    filtered = []
    cutoff = datetime.now(timezone.utc) - timedelta(hours=48)
    for item in all_news:
        title_key = item['title'].lower().strip()
        if title_key not in seen:
            seen.add(title_key)
            if item['published'] is None or item['published'] >= cutoff:
                filtered.append(item)

    # Sort by date
    filtered.sort(key=lambda x: x['published'] or datetime.min.replace(tzinfo=timezone.utc), reverse=True)

    # Build HTML
    if filtered:
        news_rows = ""
        current_cat = None
        for item in filtered:
            if item['category'] != current_cat:
                current_cat = item['category']
                news_rows += f"""
                <tr><td colspan='3' style='padding:12px 8px 4px;font-weight:bold;font-size:14px;
                    color:#4ecdc4;border-bottom:1px solid #4ecdc4;'>{current_cat}</td></tr>"""

            date_str = item['published'].strftime('%b %d, %H:%M UTC') if item['published'] else '—'
            news_rows += f"""
            <tr style='border-bottom:1px solid #2a2a3e;'>
                <td style='padding:6px 8px;color:#aaa;font-size:11px;white-space:nowrap;'>{date_str}</td>
                <td style='padding:6px 8px;'><a href="{item['link']}" style='color:#ddd;text-decoration:none;'>{item['title']}</a></td>
                <td style='padding:6px 8px;color:#888;font-size:11px;'>{item['source']}</td>
            </tr>"""

        display(HTML(f"""
        <div style='background:#1a1a2e;color:white;padding:20px;border-radius:10px;margin:10px 0;'>
            <h3 style='margin:0 0 5px 0;'>Live News Feed</h3>
            <p style='color:#aaa;font-size:11px;margin:0 0 15px 0;'>Last refreshed: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')} | Showing last 48 hours | {len(filtered)} headlines</p>
            <table style='color:white;width:100%;font-size:12px;border-collapse:collapse;'>
                {news_rows}
            </table>
        </div>
        """))
    else:
        print("No recent news found in the last 48 hours.")
else:
    display(Markdown("""**feedparser not installed.** Run `pip install feedparser` to enable the live news feed.

Manual news links:
- [Google News: TTF gas](https://news.google.com/search?q=TTF%20gas%20price%20Europe)
- [Google News: Ras Laffan](https://news.google.com/search?q=Ras%20Laffan%20LNG%20Qatar)
- [Google News: Strait of Hormuz](https://news.google.com/search?q=Strait%20of%20Hormuz%20shipping)
- [Google News: Cheniere Energy](https://news.google.com/search?q=Cheniere%20Energy%20LNG)
- [Google News: Brent crude](https://news.google.com/search?q=Brent%20crude%20oil%20Hormuz)
"""))
# Out:
#         <div style='background:#1a1a2e;color:white;padding:20px;border-radius:10px;margin:10px 0;'>
#             <h3 style='margin:0 0 5px 0;'>Live News Feed</h3>
#             <p style='color:#aaa;font-size:11px;margin:0 0 15px 0;'>Last refreshed: 2026-03-28 23:29:13 | Showing last 48 hours | 10 headlines</p>
#             <table style='color:white;width:100%;font-size:12px;border-collapse:collapse;'>
#
#                 <tr><td colspan='3' style='padding:12px 8px 4px;font-weight:bold;font-size:14px;
#                     color:#4ecdc4;border-bottom:1px solid #4ecdc4;'>Equities</td></tr>
#             <tr style='border-bottom:1px solid #2a2a3e;'>
#                 <td style='padding:6px 8px;color:#aaa;font-size:11px;white-space:nowrap;'>Mar 28, 16:06 UTC</td>
# ...

# %% [markdown]
# ---
# ## 13. Exit Criteria
#
# ### Take Profit
# - **Target 1 (€80):** Take half off. April/May injection data confirms behind pace.
# - **Target 2 (€100):** Take rest off. Full-blown supply panic, comparable to 2022.
#
# ### Stop Loss (€45)
# - Hormuz reopens AND mandate dropped to 70% AND injection data on pace. All three required.
# - €45 = pre-strike TTF level. If the market fully unwinds the supply shock premium, thesis is wrong.
#
# ### Review Triggers
# - First April injection data print
# - Any Hormuz reopening headline
# - EU mandate changes
# - Ceasefire announcements
# - TTF hitting €80 (reassess position size)
#
# ---
# *This notebook pulls live data from the AGSI API. Run all cells (Kernel → Restart & Run All) to update with the latest storage figures and thesis score.*
#
# *Data source: GIE AGSI Transparency Platform (agsi.gie.eu). API data represents status at 6AM CET, published daily at 19:30 CET.*

# %% [markdown]
# ---
# ## 14. Risk Management Framework
#
# *Inspired by Market Wizards (Schwager, 1989). The principles below are drawn from Ed Seykota, Bruce Kovner, Paul Tudor Jones, Larry Hite, Marty Schwartz, and others.*
#
# > "The most important rule of trading is to play great defence, not great offence." — Paul Tudor Jones
#
# > "Undertrade, undertrade, undertrade." — Bruce Kovner
#
# ### Portfolio-Level Circuit Breakers (Jones)
#
# | Trigger | Action | Rationale |
# |---------|--------|-----------|
# | **-10% weighted portfolio P&L** | Cut all positions by 50% | Jones's "no double-digit monthly loss" rule. Survive first, profit second. |
# | **-15% weighted portfolio P&L** | Close everything. Full reassessment. | If five correlated positions are all moving against you, the regime has changed. |
# | **-5% in a single week** | No new positions for 48 hours. Review. | Rapid drawdowns signal something fundamental has shifted. Pause and think. |
#
# ### Per-Trade Risk Audit
#
# This portfolio deliberately deviates from the standard Hite/Kovner 1-2% rule due to high conviction. The deviation is acknowledged and documented:
#
# | Position | Entry | Stop | Loss if Stopped | Weight | Portfolio Risk | Hite Compliant? |
# |----------|-------|------|----------------|--------|---------------|-----------------|
# | TTF | EUR 59.34 | EUR 45 | -24.2% | 30% | **7.3%** | No (3.6x over) |
# | LNG | $299 | $265 | -11.4% | 25% | **2.8%** | No (1.4x over) |
# | VG | $17.50 | $12 | -31.4% | 10% | **3.1%** | No (1.6x over) |
# | EQNR | $41 | $35 | -14.6% | 10% | **1.5%** | Borderline |
# | Brent | $112.50 | $95 | -15.6% | 10% | **1.6%** | Borderline |
# | HH (short) | $2.94 | $3.50 | -19.0% | 5% | **1.0%** | Yes |
# | **Total if all stops hit** | | | | | **17.3%** | |
#
# **Why this is acceptable (for a paper trade):** The stops are placed at thesis invalidation levels (Kovner's approach), not arbitrary pain thresholds. TTF at EUR 45 = pre-strike price = thesis is dead. The oversizing reflects conviction in a structurally broken refill maths, not recklessness. The portfolio-level circuit breaker at -10% is the safety net.
#
# **What a real-money version would change:** Reduce TTF to 15% weight (halves risk to 3.6%), add put options on TTF and Brent as tail hedges, and enforce strict 2% per-trade risk.
#
# ### Drawdown Protocol (Schwartz + Dennis)
#
# 1. **During a drawdown:** Reduce size, increase discipline, journal more frequently.
# 2. **Never average down.** If TTF drops to EUR 50, you do not add. You wait. (Universal across all Wizards.)
# 3. **Only size back up after recovery.** Schwartz's rule: double or triple the account before increasing position size.
# 4. **If 3+ positions hit stops in the same week:** This is a regime change (ceasefire, Hormuz reopening). Go flat and reassess from zero.
# 5. **Maintain maximum focus during losing periods** (Dennis). This is when most traders abandon discipline — and precisely when it matters most.
#
# ### Pre-Committed Crisis Responses (Kovner)
#
# *Written in advance so you do not decide in the heat of the moment. Kovner: "Know where you are getting out before you get in."*
#
# | Event | Immediate Action (within 1 hour) | Within 24 Hours |
# |-------|----------------------------------|-----------------|
# | **Ceasefire announced** | Close Brent. Reduce TTF by half. | Reassess EQNR and equities. Keep HH short. |
# | **Hormuz reopens** | Close Brent. Tighten all stops to breakeven. | If TTF drops below EUR 50, close. |
# | **Trump strikes Iranian energy** | Hold all. Move TTF stop to breakeven (EUR 59). | Consider adding to Brent if still below $120. |
# | **EU drops mandate below 70%** | Close half of TTF. | Re-run refill maths at new target level. |
# | **TTF hits TP1 (EUR 80)** | Take half off. Move stop to EUR 65. | Journal the decision and emotions. |
# | **April injection data on pace** | Tighten TTF stop to EUR 55. | If second week confirms, reduce TTF to 20% weight. |
# | **April injection data behind pace** | Hold. Thesis confirmed. | Consider moving TP2 higher if gap ratio worsens. |
#
# ### Correlation Awareness (Kovner)
#
# > Kovner stressed that multiple correlated positions create far more risk than the sum of individual trade risks. Five "1% risk" positions in correlated assets is really one 5% bet.
#
# This portfolio is **deliberately concentrated.** Positions 1-5 are all expressions of the same macro view (ME escalation + EU energy crisis). The HH short provides minimal decorrelation. In a ceasefire scenario, everything reverses together.
#
# **Weekly check:** Run the correlation matrix in Section 8. If all correlations are >0.8, you are running one big directional bet with a small hedge. That is the current reality — own it, size for it, and have the circuit breakers ready.
#
# ### Seykota's Three Questions (Weekly Review)
#
# Run these every Sunday before markets open:
#
# 1. **What is the trend?** Is TTF still above entry? Is EU storage still draining? Is the thesis intact?
# 2. **What is my risk?** Total portfolio exposure, distance to stops, correlation. Run the numbers, do not guess.
# 3. **What would I do if I had no position?** Would I enter this trade today at this price with this information? If not, why am I still in it?
#
# ### Trade Journal Template (Schwartz + Ryan)
#
# Each weekly entry in Section 11 should have three parts:
#
# | Component | What to Write | Why It Matters |
# |-----------|--------------|----------------|
# | **Data** | TTF price, EU storage %, thesis score, portfolio P&L | Objective record. No revisionism. |
# | **Decisions** | What did you do this week? What did you choose NOT to do? | Tracks both action and restraint. |
# | **Psychology** | How did you feel? Tempted to close early? Tempted to add? Anxious about a headline? | Schwartz: traders lose because they would rather lose money than admit they are wrong. The journal catches this before it costs you. |
#
# > "Everybody gets what they want out of the market." — Ed Seykota
#
# The question is whether what you want is to make money, or to be right.

# %%
# ── Risk dashboard — live portfolio risk calculations ──
import yfinance as yf

POSITIONS = {
    "TTF": {"ticker": "TTF=F", "dir": "LONG", "entry": 59.34, "stop": 45.0, "weight": 0.30},
    "LNG": {"ticker": "LNG", "dir": "LONG", "entry": 299.0, "stop": 265.0, "weight": 0.25},
    "VG": {"ticker": "VG", "dir": "LONG", "entry": 17.50, "stop": 12.0, "weight": 0.10},
    "EQNR": {"ticker": "EQNR", "dir": "LONG", "entry": 41.0, "stop": 35.0, "weight": 0.10},
    "BRENT": {"ticker": "BZ=F", "dir": "LONG", "entry": 112.50, "stop": 95.0, "weight": 0.10},
    "HH": {"ticker": "NG=F", "dir": "SHORT", "entry": 2.94, "stop": 3.50, "weight": 0.05},
}

CIRCUIT_BREAKERS = {
    "yellow": -5.0,   # -5% weekly: pause new positions
    "orange": -10.0,  # -10%: cut all by 50%
    "red": -15.0,     # -15%: close everything
}

# Fetch live prices
prices = {}
for key, pos in POSITIONS.items():
    try:
        t = yf.Ticker(pos["ticker"])
        h = t.history(period="5d")
        prices[key] = h['Close'].iloc[-1] if not h.empty else pos["entry"]
    except:
        prices[key] = pos["entry"]

# Calculate current P&L and risk metrics
rows = ""
total_weighted_pnl = 0
total_risk_if_stopped = 0

for key, pos in POSITIONS.items():
    current = prices[key]
    if pos["dir"] == "LONG":
        pnl_pct = ((current - pos["entry"]) / pos["entry"]) * 100
        loss_if_stopped = ((pos["stop"] - pos["entry"]) / pos["entry"]) * 100
        dist_to_stop = ((current - pos["stop"]) / current) * 100
    else:
        pnl_pct = ((pos["entry"] - current) / pos["entry"]) * 100
        loss_if_stopped = ((pos["entry"] - pos["stop"]) / pos["entry"]) * 100
        dist_to_stop = ((pos["stop"] - current) / current) * 100

    weighted_pnl = pnl_pct * pos["weight"]
    portfolio_risk = abs(loss_if_stopped) * pos["weight"]
    total_weighted_pnl += weighted_pnl
    total_risk_if_stopped += portfolio_risk

    pnl_color = "#00ff88" if pnl_pct >= 0 else "#ff4444"
    dist_color = "#ff4444" if dist_to_stop < 10 else "#ffaa00" if dist_to_stop < 20 else "#00ff88"

    rows += f"""
        <tr style='border-bottom:1px solid #333;'>
            <td style='padding:6px 8px;'><strong>{key}</strong></td>
            <td style='padding:6px 8px;color:{pnl_color};'>{pnl_pct:+.1f}%</td>
            <td style='padding:6px 8px;'>{portfolio_risk:.1f}%</td>
            <td style='padding:6px 8px;color:{dist_color};'>{dist_to_stop:.1f}%</td>
            <td style='padding:6px 8px;'>{pos["weight"]*100:.0f}%</td>
        </tr>"""

# Determine circuit breaker status
if total_weighted_pnl <= CIRCUIT_BREAKERS["red"]:
    cb_status = "RED — CLOSE EVERYTHING"
    cb_color = "#ff0000"
elif total_weighted_pnl <= CIRCUIT_BREAKERS["orange"]:
    cb_status = "ORANGE — CUT ALL POSITIONS BY 50%"
    cb_color = "#ff8800"
elif total_weighted_pnl <= CIRCUIT_BREAKERS["yellow"]:
    cb_status = "YELLOW — NO NEW POSITIONS FOR 48H"
    cb_color = "#ffcc00"
else:
    cb_status = "GREEN — ALL CLEAR"
    cb_color = "#00ff88"

total_pnl_color = "#00ff88" if total_weighted_pnl >= 0 else "#ff4444"

display(HTML(f"""
<div style='background:#1a1a2e;color:white;padding:20px;border-radius:10px;margin:10px 0;'>
    <h3 style='margin:0 0 15px 0;'>Risk Dashboard</h3>

    <div style='background:{cb_color}22;border:1px solid {cb_color};border-radius:8px;padding:12px;margin-bottom:15px;'>
        <span style='color:{cb_color};font-weight:bold;font-size:14px;'>CIRCUIT BREAKER: {cb_status}</span><br>
        <span style='color:#aaa;font-size:11px;'>Portfolio P&L: <span style='color:{total_pnl_color};font-weight:bold;'>{total_weighted_pnl:+.2f}%</span>
        &nbsp;|&nbsp; Max risk if all stops hit: {total_risk_if_stopped:.1f}%
        &nbsp;|&nbsp; Triggers: -5% (pause) / -10% (halve) / -15% (close)</span>
    </div>

    <table style='color:white;width:100%;font-size:13px;border-collapse:collapse;'>
        <tr style='border-bottom:2px solid #555;'>
            <th style='padding:6px 8px;text-align:left;'>Position</th>
            <th style='padding:6px 8px;text-align:left;'>Current P&L</th>
            <th style='padding:6px 8px;text-align:left;'>Risk if Stopped</th>
            <th style='padding:6px 8px;text-align:left;'>Distance to Stop</th>
            <th style='padding:6px 8px;text-align:left;'>Weight</th>
        </tr>
        {rows}
    </table>
</div>
"""))

display(Markdown(f"""
**Seykota's Three Questions:**
1. What is the trend? *(Check Section 3 — is storage still declining?)*
2. What is my risk? *(Total portfolio risk: {total_risk_if_stopped:.1f}% if all stops hit)*
3. Would I enter this trade today? *(Re-read Section 10 — does the thesis still hold?)*
"""))
# Out:
# <div style='background:#1a1a2e;color:white;padding:20px;border-radius:10px;margin:10px 0;'>
#     <h3 style='margin:0 0 15px 0;'>Risk Dashboard</h3>
#
#     <div style='background:#00ff8822;border:1px solid #00ff88;border-radius:8px;padding:12px;margin-bottom:15px;'>
#         <span style='color:#00ff88;font-weight:bold;font-size:14px;'>CIRCUIT BREAKER: GREEN — ALL CLEAR</span><br>
#         <span style='color:#aaa;font-size:11px;'>Portfolio P&L: <span style='color:#ff4444;font-weight:bold;'>-2.90%</span>
#         &nbsp;|&nbsp; Max risk if all stops hit: 17.2%
#         &nbsp;|&nbsp; Triggers: -5% (pause) / -10% (halve) / -15% (close)</span>
#     </div>
#
#     <table style='color:white;width:100%;font-size:13px;border-collapse:collapse;'>
#         <tr style='border-bottom:2px solid #555;'>
#             <th style='padding:6px 8px;text-align:left;'>Position</th>
#             <th style='padding:6px 8px;text-align:left;'>Current P&L</th>
# ...
